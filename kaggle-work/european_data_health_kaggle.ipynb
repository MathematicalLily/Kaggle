# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
dataframe = pd.read_csv('/Users/lily/Desktop/kaggle datasets/world diet behaviour/Protein_Supply_Quantity_Data.csv')

# %%
(dataframe)
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           9.7523
# 1                               Albania               0.1840          27.7469
# 2                               Algeria               0.0323          13.8360
# 3                                Angola               0.6285          15.2311
# 4                   Antigua and Barbuda               0.1535          33.1901
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.1955          22.5411
# 166                             Vietnam               0.1555          20.4466
# 167                               Yemen               0.0000          10.0122
# 168                              Zambia               0.4824           9.8925
# 169                            Zimbabwe               0.2929          11.3443
#
# ...

# %%
#looking at the data, ready to get the necessary columns. 

dataframe.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           9.7523       0.0277
# 1              Albania               0.1840          27.7469       0.0711
# 2              Algeria               0.0323          13.8360       0.0054
# 3               Angola               0.6285          15.2311       0.0277
# 4  Antigua and Barbuda               0.1535          33.1901       0.1289
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   35.9771  0.4067         0.0647
# 1                      0.0                   14.2331  1.8069         0.6274
# 2                      0.0                   26.5633  1.2916         0.6350
# 3                      0.0                   20.3882  0.1756         5.4436
# 4                      0.0                   10.5108  0.4850         8.2146
#
# ...

# %%
dataframe.shape
# Out:
# (170, 32)

# %%
dataframe1 = dataframe.iloc[:,0:29]
(dataframe1)
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           9.7523
# 1                               Albania               0.1840          27.7469
# 2                               Algeria               0.0323          13.8360
# 3                                Angola               0.6285          15.2311
# 4                   Antigua and Barbuda               0.1535          33.1901
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.1955          22.5411
# 166                             Vietnam               0.1555          20.4466
# 167                               Yemen               0.0000          10.0122
# 168                              Zambia               0.4824           9.8925
# 169                            Zimbabwe               0.2929          11.3443
#
# ...

# %%
cleaned_data = dataframe1 [['Country', 'Deaths', 'Recovered' ]]
(cleaned_data)
# Out:
#                                 Country    Deaths  Recovered
# 0                           Afghanistan  0.006186   0.123374
# 1                               Albania  0.050951   1.792636
# 2                               Algeria  0.006558   0.167572
# 3                                Angola  0.001461   0.056808
# 4                   Antigua and Barbuda  0.007143   0.190816
# ..                                  ...       ...        ...
# 165  Venezuela (Bolivarian Republic of)  0.004287   0.424399
# 166                             Vietnam  0.000036   0.001526
# 167                               Yemen  0.002062   0.004788
# 168                              Zambia  0.004564   0.290524
# 169                            Zimbabwe  0.008854   0.190964
#
# [170 rows x 3 columns]

# %%
(cleaned_data)
# Out:
#                                 Country    Deaths  Recovered
# 0                           Afghanistan  0.006186   0.123374
# 1                               Albania  0.050951   1.792636
# 2                               Algeria  0.006558   0.167572
# 3                                Angola  0.001461   0.056808
# 4                   Antigua and Barbuda  0.007143   0.190816
# ..                                  ...       ...        ...
# 165  Venezuela (Bolivarian Republic of)  0.004287   0.424399
# 166                             Vietnam  0.000036   0.001526
# 167                               Yemen  0.002062   0.004788
# 168                              Zambia  0.004564   0.290524
# 169                            Zimbabwe  0.008854   0.190964
#
# [170 rows x 3 columns]

# %%
pd = cleaned_data.iloc[0:10, 0:] 
(pd)
# Out:
#                Country    Deaths  Recovered
# 0          Afghanistan  0.006186   0.123374
# 1              Albania  0.050951   1.792636
# 2              Algeria  0.006558   0.167572
# 3               Angola  0.001461   0.056808
# 4  Antigua and Barbuda  0.007143   0.190816
# 5            Argentina  0.108227   3.905192
# 6              Armenia  0.105345   5.398410
# 7            Australia  0.003530   0.101289
# 8              Austria  0.089679   4.496870
# 9           Azerbaijan  0.031223   2.225574

# %%
#data chunking
pd.plot(x ='Country', y='Recovered', kind = 'bar')

# %%
#European data 
(dataframe1)
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           9.7523
# 1                               Albania               0.1840          27.7469
# 2                               Algeria               0.0323          13.8360
# 3                                Angola               0.6285          15.2311
# 4                   Antigua and Barbuda               0.1535          33.1901
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.1955          22.5411
# 166                             Vietnam               0.1555          20.4466
# 167                               Yemen               0.0000          10.0122
# 168                              Zambia               0.4824           9.8925
# 169                            Zimbabwe               0.2929          11.3443
#
# ...

# %%
dataframe1.head(10) #getting A. category data values.
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           9.7523       0.0277
# 1              Albania               0.1840          27.7469       0.0711
# 2              Algeria               0.0323          13.8360       0.0054
# 3               Angola               0.6285          15.2311       0.0277
# 4  Antigua and Barbuda               0.1535          33.1901       0.1289
# 5            Argentina               0.1704          31.9799       0.0097
# 6              Armenia               0.0411          22.8846       0.1438
# 7            Australia               0.2914          32.9787       0.0740
# 8              Austria               0.6150          30.0009       0.3376
# 9           Azerbaijan               0.3465          16.3039       0.0596
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                   0.0000                   35.9771  0.4067         0.0647
# ...

# %%
#getting european data as an array
european_a = dataframe1.iloc[[1,6,8,9,13,14,18,21,35,37,38,39,46,50,51,55,56,58,66
                             ,67,72,74,78,86,90,91,97,102,108,114,115,122,123,125,126,
                             141,145,146,154,157,159 ], [0,24,25,26,27,28]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
(european_a)
# Out:
#                     Country  Obesity Undernourished  Confirmed    Deaths  \
# 1                   Albania     22.3            6.2   2.967301  0.050951
# 6                   Armenia     20.9            4.3   5.681225  0.105345
# 8                   Austria     21.9           <2.5   4.739982  0.089679
# 9                Azerbaijan     19.9           <2.5   2.285536  0.031223
# 13                  Belarus     26.6           <2.5   2.740896  0.018912
# 14                  Belgium     24.5           <2.5   6.286322  0.185428
# 18   Bosnia and Herzegovina     19.4           <2.5   3.762085  0.145535
# 21                 Bulgaria     27.4            3.6   3.227256  0.134416
# 35                  Croatia     27.1           <2.5   5.848905  0.127960
# 37                   Cyprus     22.6            5.6   2.621707  0.017481
# 38                  Czechia     28.5           <2.5   9.612841  0.159845
# 39                  Denmark     21.3           <2.5   3.463218  0.038017
# ...

# %%
dataframe1.head(168)
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           9.7523
# 1                               Albania               0.1840          27.7469
# 2                               Algeria               0.0323          13.8360
# 3                                Angola               0.6285          15.2311
# 4                   Antigua and Barbuda               0.1535          33.1901
# ..                                  ...                  ...              ...
# 163                          Uzbekistan               0.0588          20.0246
# 164                             Vanuatu               0.0078          19.8713
# 165  Venezuela (Bolivarian Republic of)               0.1955          22.5411
# 166                             Vietnam               0.1555          20.4466
# 167                               Yemen               0.0000          10.0122
#
# ...

# %%
european_b = dataframe1.iloc[[13,14,18,21], [0,24,25,26,27,28]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
(european_b)
# Out:
#                    Country  Obesity Undernourished  Confirmed    Deaths  \
# 13                 Belarus     26.6           <2.5   2.740896  0.018912
# 14                 Belgium     24.5           <2.5   6.286322  0.185428
# 18  Bosnia and Herzegovina     19.4           <2.5   3.762085  0.145535
# 21                Bulgaria     27.4            3.6   3.227256  0.134416
#
#     Recovered
# 13   2.612704
# 14   0.000000
# 18   2.960317
# 21   2.788956

# %%
df = european_a.to_csv('european covid data')
